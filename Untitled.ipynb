# %% [markdown]
# # Preliminaries

# %%
import pandas as pd

pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',1000)

# %%
fname = "data/PHL_2024_FINDEX_v01_M_CSV.zip"
df_raw = pd.read_csv(fname, compression='zip')
df_raw.head()
# Out:
#    year      economy economycode                                     regionwb  \
# 0  2024  Philippines         PHL  East Asia & Pacific (excluding high income)
# 1  2024  Philippines         PHL  East Asia & Pacific (excluding high income)
# 2  2024  Philippines         PHL  East Asia & Pacific (excluding high income)
# 3  2024  Philippines         PHL  East Asia & Pacific (excluding high income)
# 4  2024  Philippines         PHL  East Asia & Pacific (excluding high income)
#
#    pop_adult  wpid_random       wgt  female  age  educ  inc_q  emp_in  \
# 0   82023644    160484868  0.254052       2   52     2      2       2
# 1   82023644    186479019  1.368970       2   18     2      1       2
# 2   82023644    174179325  4.521343       1   72     1      1       2
# 3   82023644    170544156  0.387396       2   29     1      2       1
# 4   82023644    142951658  0.344029       2   50     3      5       1
#
#    urbanicity  account_fin  account_mob  account  dig_account  borrowed  \
# ...

# %%
df_raw.describe()
# Out:
#          year   pop_adult   wpid_random          wgt       female  \
# count  1000.0      1000.0  1.000000e+03  1000.000000  1000.000000
# mean   2024.0  82023644.0  1.614321e+08     1.000000     1.434000
# std       0.0         0.0  2.912491e+07     1.153349     0.495873
# min    2024.0  82023644.0  1.111603e+08     0.131551     1.000000
# 25%    2024.0  82023644.0  1.350750e+08     0.228027     1.000000
# 50%    2024.0  82023644.0  1.638527e+08     0.553650     1.000000
# 75%    2024.0  82023644.0  1.864979e+08     1.231914     2.000000
# max    2024.0  82023644.0  2.110807e+08     4.521343     2.000000
#
#                age        educ        inc_q       emp_in   urbanicity  \
# count  1000.000000  1000.00000  1000.000000  1000.000000  1000.000000
# mean     41.506000     1.69800     3.215000     1.431000     1.380000
# std      17.422672     0.60594     1.413072     0.495464     0.485629
# min      15.000000     1.00000     1.000000     1.000000     1.000000
# ...

# %%
(df_raw['borrowed']*df_raw['wgt']).sum()/df_raw['wgt'].sum()
# Out:
# np.float64(0.719743983120219)

# %%
df_raw.columns
# Out:
# Index(['year', 'economy', 'economycode', 'regionwb', 'pop_adult',
#        'wpid_random', 'wgt', 'female', 'age', 'educ',
#        ...
#        'con30h', 'con31a', 'con31b', 'con31c', 'con31d', 'con31e', 'con31f',
#        'con31g', 'con31h', 'con32'],
#       dtype='object', length=183)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 183 entries, year to con32
# dtypes: float64(132), int64(48), object(3)
# memory usage: 1.4+ MB

# %%
df_raw.shape
# Out:
# (1000, 183)
